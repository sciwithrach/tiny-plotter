# %%
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
adata = sc.read("mouse_processed.h5ad")
adata

# %%
sc.pl.umap(
    adata,                          # object to plot
    color = [                       # list of metadata to subplot within square brackets
        'sample',                   
        'plate',
        'cell_type',
        'MYO7A',                    # HC
        'log1p_total_counts',       # log1p READ counts
        'log1p_n_genes_by_counts',  # log1p GENE counts    
        ],
    ncols = 2,                      # number of columns
    frameon = False,                # hide axes
    vmax='p99'                      # restrict to top 99% of expression
)
